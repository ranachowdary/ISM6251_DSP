# %% [markdown]
# # ICP01 JUPYTER INSTALL

# %% [markdown]
# # SHANMUKA RANA PRATHAP CHOWDARY PONNAGANTI
# ![WhatsApp%20Image%202023-02-13%20at%2010.25.53%20PM.jpeg](attachment:WhatsApp%20Image%202023-02-13%20at%2010.25.53%20PM.jpeg)
# This is shanmuka rana prathap chowdary ponnaganti currently pursuing my masters in business analaytics and information systems at university of south florida. im currently in 2nd semeter.

# %%
print('hello world')
# Out:
# hello world
